# %% [markdown]
# # SDG Test Ground

# %%
#Import dependencies 
# %matplotlib inline
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import matplotlib.lines as mlines

# %% [markdown]
# ## Indicator Codes & Names

# %%
WDIData = os.path.join('resources', 'WDIData.csv')
original_df = pd.read_csv(WDIData)

indicators = original_df['Indicator Name']
indicators = indicators.unique()
print(len(indicators))
indicators[0:11]
# Out:
# 1429
# array(['Access to clean fuels and technologies for cooking (% of population)',
#        'Access to electricity (% of population)',
#        'Access to electricity, rural (% of rural population)',
#        'Access to electricity, urban (% of urban population)',
#        'Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)',
#        'Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)',
#        'Account ownership at a financial institution or with a mobile-money-service provider, male (% of population ages 15+)',
#        'Account ownership at a financial institution or with a mobile-money-service provider, older adults (% of population ages 25+)',
#        'Account ownership at a financial institution or with a mobile-money-service provider, poorest 40% (% of population ages 15+)',
#        'Account ownership at a financial institution or with a mobile-money-service provider, primary education or less (% of population ages 15+)',
#        'Account ownership at a financial institution or with a mobile-money-service provider, richest 60% (% of population ages 15+)'],
#       dtype=object)

# %%
WDISeries = os.path.join('resources', 'WDISeries.csv')
series_df = pd.read_csv(WDISeries)
series_df = series_df.iloc[:,0:3]

topic_df = series_df["Topic"].str.split(":", n=1, expand = True)
series_df.insert(1, "Topic Parent", topic_df[0])
# series_df.insert(2, "Topic Child", topic_df[1])
print(len(series_df))
series_df.head()
# Out:
# 1429
#          Series Code Topic Parent                                 Topic  \
# 0     AG.AGR.TRAC.NO  Environment  Environment: Agricultural production
# 1  AG.CON.FERT.PT.ZS  Environment  Environment: Agricultural production
# 2     AG.CON.FERT.ZS  Environment  Environment: Agricultural production
# 3     AG.LND.AGRI.K2  Environment                 Environment: Land use
# 4     AG.LND.AGRI.ZS  Environment                 Environment: Land use
#
#                                       Indicator Name
# 0                   Agricultural machinery, tractors
# 1  Fertilizer consumption (% of fertilizer produc...
# 2  Fertilizer consumption (kilograms per hectare ...
# 3                         Agricultural land (sq. km)
# 4                 Agricultural land (% of land area)

# %% [markdown]
# ## Parent Topics

# %%
topics = series_df["Topic Parent"].unique()
print(len(topics))
topics
# Out:
# 12
# array(['Environment', 'Economic Policy & Debt', 'Infrastructure',
#        'Financial Sector', 'World Bank, International Debt Statistics.',
#        'Public Sector', 'Private Sector & Trade',
#        'Social Protection & Labor', 'Education', 'Gender', 'Health',
#        'Poverty'], dtype=object)

# %% [markdown]
# ## Indicator Codes

# %%
substring = 'SI.POV'

agr = series_df[series_df['Series Code'].str.startswith(substring)]
print(len(agr))
agr
# Out:
# 13
#          Series Code Topic Parent                         Topic  \
# 1074     SI.POV.DDAY      Poverty        Poverty: Poverty rates
# 1075     SI.POV.GAPS      Poverty        Poverty: Poverty rates
# 1076     SI.POV.GINI      Poverty  Poverty: Income distribution
# 1077     SI.POV.LMIC      Poverty        Poverty: Poverty rates
# 1078  SI.POV.LMIC.GP      Poverty        Poverty: Poverty rates
# 1079     SI.POV.NAGP      Poverty        Poverty: Poverty rates
# 1080     SI.POV.NAHC      Poverty        Poverty: Poverty rates
# 1081     SI.POV.RUGP      Poverty        Poverty: Poverty rates
# 1082     SI.POV.RUHC      Poverty        Poverty: Poverty rates
# 1083     SI.POV.UMIC      Poverty        Poverty: Poverty rates
# 1084  SI.POV.UMIC.GP      Poverty        Poverty: Poverty rates
# 1085     SI.POV.URGP      Poverty        Poverty: Poverty rates
# 1086     SI.POV.URHC      Poverty        Poverty: Poverty rates
#
#                                          Indicator Name
# 1074  Poverty headcount ratio at $1.90 a day (2011 P...
# 1075          Poverty gap at $1.90 a day (2011 PPP) (%)
# 1076                   GINI index (World Bank estimate)
# 1077  Poverty headcount ratio at $3.20 a day (2011 P...
# 1078          Poverty gap at $3.20 a day (2011 PPP) (%)
# 1079          Poverty gap at national poverty lines (%)
# 1080  Poverty headcount ratio at national poverty li...
# 1081    Rural poverty gap at national poverty lines (%)
# 1082  Rural poverty headcount ratio at national pove...
# 1083  Poverty headcount ratio at $5.50 a day (2011 P...
# 1084          Poverty gap at $5.50 a day (2011 PPP) (%)
# 1085    Urban poverty gap at national poverty lines (%)
# 1086  Urban poverty headcount ratio at national pove...

# %% [markdown]
# ### Translate Code to Indicator Name

# %%
code = 'NY.GNP.PCAP.CD'
select = series_df.loc[series_df['Series Code']==code]
select
# Out:
#         Series Code            Topic Parent  \
# 701  NY.GNP.PCAP.CD  Economic Policy & Debt
#
#                                                  Topic  \
# 701  Economic Policy & Debt: National accounts: Atl...
#
#                                  Indicator Name
# 701  GNI per capita, Atlas method (current US$)

# %% [markdown]
# ### Indicator Values

# %%
# selection = 'GNI per capita, Atlas method (current US$)'
select = original_df.loc[original_df['Indicator Code']==code]
print(len(select))
select
# Out:
# 264
#                                              Country Name Country Code  \
# 501                                            Arab World          ARB
# 1930                               Caribbean small states          CSS
# 3359                       Central Europe and the Baltics          CEB
# 4788                           Early-demographic dividend          EAR
# 6217                                  East Asia & Pacific          EAS
# 7646          East Asia & Pacific (excluding high income)          EAP
# 9075           East Asia & Pacific (IDA & IBRD countries)          TEA
# 10504                                           Euro area          EMU
# 11933                               Europe & Central Asia          ECS
# 13362       Europe & Central Asia (excluding high income)          ECA
# 14791        Europe & Central Asia (IDA & IBRD countries)          TEC
# 16220                                      European Union          EUU
# 17649            Fragile and conflict affected situations          FCS
# 19078              Heavily indebted poor countries (HIPC)          HPC
# 20507                                         High income          HIC
# 21936                                           IBRD only          IBD
# 23365                                    IDA & IBRD total          IBT
# 24794                                           IDA blend          IDB
# 26223                                            IDA only          IDX
# 27652                                           IDA total          IDA
# 29081                           Late-demographic dividend          LTE
# 30510                           Latin America & Caribbean          LCN
# 31939   Latin America & Caribbean (excluding high income)          LAC
# 33368   Latin America & the Caribbean (IDA & IBRD coun...          TLA
# 34797        Least developed countries: UN classification          LDC
# 36226                                 Low & middle income          LMY
# 37655                                          Low income          LIC
# 39084                                 Lower middle income          LMC
# 40513                          Middle East & North Africa          MEA
# 41942   Middle East & North Africa (excluding high inc...          MNA
# ...                                                   ...          ...
# 334887                                             Sweden          SWE
# 336316                                        Switzerland          CHE
# 337745                               Syrian Arab Republic          SYR
# 339174                                         Tajikistan          TJK
# 340603                                           Tanzania          TZA
# 342032                                           Thailand          THA
# 343461                                        Timor-Leste          TLS
# 344890                                               Togo          TGO
# 346319                                              Tonga          TON
# 347748                                Trinidad and Tobago          TTO
# 349177                                            Tunisia          TUN
# 350606                                             Turkey          TUR
# 352035                                       Turkmenistan          TKM
# 353464                           Turks and Caicos Islands          TCA
# 354893                                             Tuvalu          TUV
# 356322                                             Uganda          UGA
# 357751                                            Ukraine          UKR
# 359180                               United Arab Emirates          ARE
# 360609                                     United Kingdom          GBR
# 362038                                      United States          USA
# 363467                                            Uruguay          URY
# 364896                                         Uzbekistan          UZB
# 366325                                            Vanuatu          VUT
# 367754                                      Venezuela, RB          VEN
# 369183                                            Vietnam          VNM
# 370612                              Virgin Islands (U.S.)          VIR
# 372041                                 West Bank and Gaza          PSE
# 373470                                        Yemen, Rep.          YEM
# 374899                                             Zambia          ZMB
# 376328                                           Zimbabwe          ZWE
#
#                                     Indicator Name  Indicator Code  1960  \
# 501     GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 1930    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 3359    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 4788    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 6217    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 7646    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 9075    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 10504   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 11933   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 13362   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 14791   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 16220   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 17649   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 19078   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 20507   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 21936   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 23365   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 24794   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 26223   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 27652   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 29081   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 30510   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 31939   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 33368   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 34797   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 36226   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 37655   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 39084   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 40513   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 41942   GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# ...                                            ...             ...   ...
# 334887  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 336316  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 337745  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 339174  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 340603  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 342032  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 343461  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 344890  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 346319  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 347748  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 349177  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 350606  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 352035  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 353464  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 354893  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 356322  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 357751  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 359180  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 360609  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 362038  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 363467  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 364896  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 366325  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 367754  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 369183  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 370612  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 372041  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 373470  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 374899  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
# 376328  GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD   NaN
#
#         1961         1962         1963         1964         1965  ...  \
# 501      NaN          NaN          NaN          NaN          NaN  ...
# 1930     NaN          NaN          NaN          NaN          NaN  ...
# 3359     NaN          NaN          NaN          NaN          NaN  ...
# 4788     NaN          NaN          NaN   169.550384   180.525954  ...
# 6217     NaN   142.719774   156.136131   174.731222   193.500256  ...
# 7646     NaN    71.307032    77.570267    86.234680    97.707052  ...
# 9075     NaN    72.122245    78.447667    87.202716    98.799531  ...
# 10504    NaN  1087.329531  1191.975117  1313.069662  1449.395082  ...
# 11933    NaN          NaN          NaN          NaN          NaN  ...
# 13362    NaN          NaN          NaN          NaN          NaN  ...
# 14791    NaN          NaN          NaN          NaN          NaN  ...
# 16220    NaN          NaN          NaN          NaN          NaN  ...
# 17649    NaN          NaN          NaN          NaN          NaN  ...
# 19078    NaN          NaN          NaN          NaN          NaN  ...
# 20507    NaN  1542.115575  1634.879951  1757.496754  1904.517480  ...
# 336316  85800.000000  82110.000000  81120.000000  84410.000000   NaN
# 337745           NaN           NaN           NaN           NaN   NaN
# 339174   1250.000000   1110.000000   1000.000000   1010.000000   NaN
# 340603    980.000000    970.000000    970.000000   1020.000000   NaN
# 342032   5710.000000   5690.000000   5950.000000   6610.000000   NaN
# 343461   3080.000000   2370.000000   1810.000000   1820.000000   NaN
# 344890    640.000000    610.000000    600.000000    660.000000   NaN
# 346319   4520.000000   4300.000000   4250.000000   4300.000000   NaN
# 347748  19130.000000  16720.000000  15970.000000  15950.000000   NaN
# 349177   3960.000000   3760.000000   3520.000000   3500.000000   NaN
# 350606  11960.000000  11180.000000  10900.000000  10420.000000   NaN
# 352035   7030.000000   6820.000000   6380.000000   6740.000000   NaN
# 353464  23800.000000  25040.000000  25410.000000  26740.000000   NaN
# 354893   5440.000000   5070.000000   4810.000000   5430.000000   NaN
# 356322    700.000000    660.000000    620.000000    620.000000   NaN
# 357751   2650.000000   2310.000000   2260.000000   2660.000000   NaN
# 359180  42860.000000  40570.000000  38550.000000  40880.000000   NaN
# 360609  44280.000000  42990.000000  41370.000000  41770.000000   NaN
# 362038  56720.000000  57160.000000  59030.000000  63080.000000   NaN
# 363467  15640.000000  14980.000000  14900.000000  15650.000000   NaN
# 364896   2600.000000   2660.000000   2350.000000   2020.000000   NaN
# 366325   2910.000000   2850.000000   2880.000000   3130.000000   NaN
# 367754           NaN           NaN           NaN           NaN   NaN
# 369183   1970.000000   2080.000000   2120.000000   2360.000000   NaN
# 370612           NaN           NaN           NaN           NaN   NaN
# 372041   3380.000000   3460.000000   3520.000000   3710.000000   NaN
# 373470           NaN           NaN           NaN           NaN   NaN
# 374899   1580.000000   1380.000000   1300.000000   1430.000000   NaN
# 376328   1280.000000   1290.000000   1370.000000   1790.000000   NaN
#
# [264 rows x 64 columns]

# %%
SDGTiers = os.path.join('resources', 'SDGTiers.csv')
tiers_df = pd.read_csv(SDGTiers, header=1)
tiers_df = tiers_df.iloc[:,[1,2,6]]
tiers_df = tiers_df.dropna()
tiers_df.head()
# Out:
#                                               Target  \
# 1  1.1 By 2030, eradicate extreme poverty for all...
# 2  1.2 By 2030, reduce at least by half the propo...
# 3                                                 \n
# 4  1.3 Implement nationally appropriate social pr...
# 5  1.4 By 2030, ensure that all men and women, in...
#
#                                            Indicator  \
# 1  1.1.1 Proportion of population below the inter...
# 2  1.2.1 Proportion of population living below th...
# 3  1.2.2 Proportion of men, women and children of...
# 4  1.3.1 Proportion of population covered by soci...
# 5  1.4.1 Proportion of population living in house...
#
#   Updated Tier Classification \n(by IAEG-SDG Members)
# 1                                             Tier I
# 2                                             Tier I
# 3                                            Tier II
# 4                                            Tier II
# 5                                             Tier I

# %% [markdown]
# ## API Calls

# %%
import json
import requests
import datetime 
from datetime import date
from pprint import pprint

# %%
# Start url query
url = "https://api.worldbank.org/v2/country/WLD/indicator/SP.POP.TOTL?format=json"
response = requests.get(url).json()
results = pprint(response[1])
results
# Out:
# [{'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2019',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': None},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2018',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 7594270356},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2017',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 7510990456},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2016',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 7426103221},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2015',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 7340548192},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2014',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 7255653881},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2013',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 7170961674},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2012',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 7086993625},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2011',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 7004011262},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2010',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6922947261},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2009',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6840591577},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2008',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6757887172},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2007',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6675130418},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2006',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6593623202},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2005',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6512602867},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2004',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6432374971},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2003',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6352677699},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2002',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6273526441},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2001',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6194460444},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2000',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6115108363},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1999',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 6035284135},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1998',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5954810550},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1997',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5873071768},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1996',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5790454220},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1995',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5707533023},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1994',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5622575421},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1993',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5538448726},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1992',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5453393960},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1991',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5369210095},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1990',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5281340078},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1989',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5190965222},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1988',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5102293348},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1987',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 5013576387},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1986',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4925801334},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1985',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4840155168},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1984',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4756998073},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1983',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4675367633},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1982',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4593454253},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1981',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4512268962},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1980',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4434021975},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1979',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4357793599},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1978',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4282341460},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1977',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4208770941},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1976',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4136393107},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1975',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 4063806523},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1974',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 3989385034},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1973',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 3913217944},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1972',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 3837726171},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1971',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 3761307048},
#  {'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '1970',
#   'decimal': 0,
#   'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#   'obs_status': '',
#   'unit': '',
#   'value': 3683676306}]

# %%
# Set up empty dataframe
columns = ['Code','Indicator','Country','Year','Value']
values_df = pd.DataFrame(columns=columns, index=[0])

# %%
# Parameters
code = 'SP.POP.TOTL'
country = 'WLD'

# API call
url = f"https://api.worldbank.org/v2/country/{country}/indicator/{code}?format=json"
response = requests.get(url).json()
results = response[1]

# Iterate through each row (one year each)
for i in range(len(results)):
    row = []
    # Code
    row.append(results[i]['indicator']['id'])
    # Indicator
    row.append(results[i]['indicator']['value'])
    # Country
    row.append(results[i]['country']['value'])
    # Year
    row.append(results[i]['date'])
    # Value
    row.append(results[i]['value'])
    # Append row
    values_df.loc[i,:] = row

values_df = values_df.dropna()
values_df
# Out:
#            Code          Indicator Country  Year       Value
# 1   SP.POP.TOTL  Population, total   World  2018  7594270356
# 2   SP.POP.TOTL  Population, total   World  2017  7510990456
# 3   SP.POP.TOTL  Population, total   World  2016  7426103221
# 4   SP.POP.TOTL  Population, total   World  2015  7340548192
# 5   SP.POP.TOTL  Population, total   World  2014  7255653881
# 6   SP.POP.TOTL  Population, total   World  2013  7170961674
# 7   SP.POP.TOTL  Population, total   World  2012  7086993625
# 8   SP.POP.TOTL  Population, total   World  2011  7004011262
# 9   SP.POP.TOTL  Population, total   World  2010  6922947261
# 10  SP.POP.TOTL  Population, total   World  2009  6840591577
# 11  SP.POP.TOTL  Population, total   World  2008  6757887172
# 12  SP.POP.TOTL  Population, total   World  2007  6675130418
# 13  SP.POP.TOTL  Population, total   World  2006  6593623202
# 14  SP.POP.TOTL  Population, total   World  2005  6512602867
# 15  SP.POP.TOTL  Population, total   World  2004  6432374971
# 16  SP.POP.TOTL  Population, total   World  2003  6352677699
# 17  SP.POP.TOTL  Population, total   World  2002  6273526441
# 18  SP.POP.TOTL  Population, total   World  2001  6194460444
# 19  SP.POP.TOTL  Population, total   World  2000  6115108363
# 20  SP.POP.TOTL  Population, total   World  1999  6035284135
# 21  SP.POP.TOTL  Population, total   World  1998  5954810550
# 22  SP.POP.TOTL  Population, total   World  1997  5873071768
# 23  SP.POP.TOTL  Population, total   World  1996  5790454220
# 24  SP.POP.TOTL  Population, total   World  1995  5707533023
# 25  SP.POP.TOTL  Population, total   World  1994  5622575421
# 26  SP.POP.TOTL  Population, total   World  1993  5538448726
# 27  SP.POP.TOTL  Population, total   World  1992  5453393960
# 28  SP.POP.TOTL  Population, total   World  1991  5369210095
# 29  SP.POP.TOTL  Population, total   World  1990  5281340078
# 30  SP.POP.TOTL  Population, total   World  1989  5190965222
# 31  SP.POP.TOTL  Population, total   World  1988  5102293348
# 32  SP.POP.TOTL  Population, total   World  1987  5013576387
# 33  SP.POP.TOTL  Population, total   World  1986  4925801334
# 34  SP.POP.TOTL  Population, total   World  1985  4840155168
# 35  SP.POP.TOTL  Population, total   World  1984  4756998073
# 36  SP.POP.TOTL  Population, total   World  1983  4675367633
# 37  SP.POP.TOTL  Population, total   World  1982  4593454253
# 38  SP.POP.TOTL  Population, total   World  1981  4512268962
# 39  SP.POP.TOTL  Population, total   World  1980  4434021975
# 40  SP.POP.TOTL  Population, total   World  1979  4357793599
# 41  SP.POP.TOTL  Population, total   World  1978  4282341460
# 42  SP.POP.TOTL  Population, total   World  1977  4208770941
# 43  SP.POP.TOTL  Population, total   World  1976  4136393107
# 44  SP.POP.TOTL  Population, total   World  1975  4063806523
# 45  SP.POP.TOTL  Population, total   World  1974  3989385034
# 46  SP.POP.TOTL  Population, total   World  1973  3913217944
# 47  SP.POP.TOTL  Population, total   World  1972  3837726171
# 48  SP.POP.TOTL  Population, total   World  1971  3761307048
# 49  SP.POP.TOTL  Population, total   World  1970  3683676306

# %% [markdown]
# ## Cleaning the Data
# ### Datasets included:
#  - The World Bank's World Development Indicators Data
#  - United Nations Development Program Human Development Reports
#    - Human Development Index
#    - Education Index
#    - Gender

# %%
filepath = os.path.join('resources', 'indicator_df.csv')
indicator_df = pd.read_csv(filepath, header=0)

filepath = os.path.join('resources','HDI_df.csv')
hdi_df = pd.read_csv(filepath)

filepath = filepath = os.path.join('resources','undp_hdr_education-index.csv')
edu_index_df = pd.read_csv(filepath)

filepath = filepath = os.path.join('resources','undp_hdr_gender-inequality-index.csv')
gii_df = pd.read_csv(filepath)

filepath= os.path.join('resources', 'WDISeries.csv')
series_df = pd.read_csv(filepath, header=0)

# %%
#Pull all in all indicicators from 1990-2019
full_ind_1990_2019 = wdi_data_df[["Country Name","Country Code","Indicator Name","Indicator Code",
                                  "1990","1991","1992","1993","1994","1995","1996","1997","1998","1999",
                                  "2000","2001","2002","2003","2004","2005","2006","2007","2008","2009",
                                  "2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"]]

# %%
#Reformat years from columns to rows
full_ind_reformatted = pd.melt(full_ind_1990_2019, id_vars =["Country Name","Country Code","Indicator Name","Indicator Code"], 
                               value_vars=["1990","1991","1992","1993","1994","1995","1996","1997","1998","1999",
                                           "2000","2001","2002","2003","2004","2005","2006","2007","2008","2009",
                                           "2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"])

# %%
#Drop all NaN from full 1990-2019 dataset 
ind_nan_dropped = full_ind_reformatted.dropna()
ind_nan_dropped_renamed = ind_nan_dropped.rename(columns={"Country Name":"country_name","Country Code":"country_code","Indicator Name":"indicator_name","Indicator Code":"indicator_code","variable":"year"})

# %%
#Read in indicator topic data
code_topics_df = series_df[["Series Code","Topic"]]
code_topics_renamed = code_topics_df.rename(columns={"Series Code":"series_code","Topic":"topic"})

# %%
#Merge indicators and topics
indicators_and_topics = pd.merge(ind_nan_dropped_renamed, code_topics_renamed, left_on = ["indicator_code"], right_on=["series_code"])
indicators_and_topics.head()

# %%
#Reformat the HDI dataframe
hdi_reformatted = pd.melt(hdi_df, id_vars =["Country"], 
                               value_vars=["1990","1991","1992","1993","1994","1995","1996","1997","1998","1999",
                                           "2000","2001","2002","2003","2004","2005","2006","2007","2008","2009",
                                           "2010","2011","2012","2013","2014","2015","2016","2017","2018"]) 
hdi_reformatted.head()

# %%
#Merge primary indicators and HDI
indicators_hdi = pd.merge(indicators_and_topics, hdi_reformatted, left_on = ["country_name", "year"], right_on=["Country", "variable"])
indicators_hdi.head()

# %%
indicators_hdi_dropped = indicators_hdi.drop(["series_code","Country", "variable"], axis=1)
indicators_hdi_renamed = indicators_hdi_dropped.rename(columns={"value_x":"value","value_y":"hdi"})
indicators_hdi_renamed["category"] = indicators_hdi_renamed["topic"].str.split(':').str[0]
indicators_hdi_renamed["subcategory"] = indicators_hdi_renamed["topic"].str.split(':').str[1]
indicators_hdi_renamed.head()

# %%
twb_wdi_indicators_final = indicators_hdi_renamed[["country_name","country_code","indicator_name","indicator_code","topic","category","subcategory","year","value","hdi"]]
twb_wdi_indicators_final.head()

# %%
#Pull out just the WDI values
wdi_values = twb_wdi_indicators_final[["country_name","indicator_name","year","value","hdi"]]
wdi_values.head()

# %%
#Select the relevent columns from the Gender Inequality Index dataframe
gii_2014_2018 = gii_df[["Country","2014","2015","2016","2017","2018"]]

#Add column for indicator name
gii_2014_2018["indicator_name"] = "Gender Inequality Index"

#Pull out space from Country column values
gii_2014_2018["country_name"] = gii_2014_2018["Country"].str.split(" ").str[1]

# %%
#Pivot years
gii_2014_2018_pivot = pd.melt(gii_2014_2018, id_vars =["country_name","indicator_name"], 
                               value_vars=["2014","2015","2016","2017","2018"])

# %%
#Add in HDI
gii_hdi_combined = pd.merge(gii_2014_2018_pivot, hdi_reformatted, how="left",
                            left_on=["country_name", "variable"], 
                            right_on=["Country", "variable"])

# %%
#Rename columns
gii_hdi_renamed = gii_hdi_combined.rename(columns={"variable":"year", "value_x":"value","value_y":"hdi"})

#Select final dataframe columns
gii_hdi = gii_hdi_renamed[["country_name","indicator_name","year","value","hdi"]]

#Preview GII dataframe
gii_hdi.head()

# %%
#Select the relevent columns from the Gender Inequality Index dataframe
ei_2014_2018 = edu_index_df[["Country","2014","2015","2016","2017","2018"]]

#Add column for indicator name
ei_2014_2018["indicator_name"] = "Education Index"

#Pull out space from Country column values
ei_2014_2018["country_name"] = ei_2014_2018["Country"].str.split(" ").str[1]

# %%
#Pivot years
ei_2014_2018_pivot = pd.melt(ei_2014_2018, id_vars =["country_name","indicator_name"], 
                               value_vars=["2014","2015","2016","2017","2018"])

# %%
#Add in HDI
ei_hdi_combined = pd.merge(ei_2014_2018_pivot, hdi_reformatted, how="left",
                            left_on=["country_name", "variable"], 
                            right_on=["Country", "variable"])

# %%
#Rename columns
ei_hdi_renamed = ei_hdi_combined.rename(columns={"variable":"year", "value_x":"value","value_y":"hdi"})

#Select final dataframe columns
ei_hdi = ei_hdi_renamed[["country_name","indicator_name","year","value","hdi"]]

#Preview GII dataframe
ei_hdi.head()

# %%
#Create combined indicators dataframe from both WDI and UNDP datasets
all_indicators = [wdi_values, gii_hdi, ei_hdi]
combined_indicators = pd.concat(all_indicators)

#Drop ".." rows
dropped_non_float = combined_indicators[combined_indicators.value != ".."]
dropped_non_float = dropped_non_float[dropped_non_float.hdi != ".."]

#Asign value and hdi columns as floats
dropped_non_float["value"] = dropped_non_float["value"].astype(float)
dropped_non_float["hdi"] = dropped_non_float["hdi"].astype(float)
dropped_non_float.head()

# %%
combined_indicators_final = dropped_non_float
combined_indicators_final.dtypes

# %% [markdown]
# ## Working with Primary Indicators
# Indicators tracked by the most countries over the most years

# %%
#Set chart style for all included charts in notebook
plt.style.use('seaborn-darkgrid')

# %%
#Pull out primary indicators (most commonly tracked by countries over the years)
common_indicators = [
    "Population, total",
    "Agriculture, forestry, and fishing, value added (% of GDP)",
    "Life expectancy at birth, total (years)",
    "GDP (current US$)",
    "GDP per capita (current US$)",
    "GNI per capita, Atlas method (current US$)",
    "Employers, total (% of total employment) (modeled ILO estimate)"]

primary_indicators = combined_indicators_final[combined_indicators_final['indicator_name'].isin(common_indicators) ]

filepath = os.path.join('resources','primary_indicators.csv')
primary_indicators.to_csv(filepath)

primary_indicators.head()

# %%
#Create Agricultural v. HDI chart
agri_values = primary_indicators.loc[(primary_indicators['indicator_name']=='Agriculture, forestry, and fishing, value added (% of GDP)')]

# defining variables
x = agri_values['value']
y = agri_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Agricultural Contribution to GDP (%)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Agricultural Contribution vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Agriculture_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Life Expectancy v. HDI chart
life_values = primary_indicators.loc[(primary_indicators['indicator_name']=='Life expectancy at birth, total (years)')]

# defining variables
x = life_values['value']
y = life_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Life expectancy at birth (years)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Life Expectancy vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Life-expectancy_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create GDP v. HDI chart
gdp_values = primary_indicators.loc[(primary_indicators['indicator_name']=='GDP (current US$)')]

# defining variables
x = gdp_values['value']
y = gdp_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('GDP (US $)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Gross Domestic Product vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'GDP_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Employment v. HDI chart

GNI_values = primary_indicators.loc[(primary_indicators['indicator_name']=='GNI per capita, Atlas method (current US$)')]

# defining variables
x = GNI_values['value']
y = GNI_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('GNI per capita, (current US$)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Gross National Income vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'GNI_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Employment v. HDI chart
employment_values = primary_indicators.loc[(primary_indicators['indicator_name']=='Employers, total (% of total employment) (modeled ILO estimate)')]

# defining variables
x = employment_values['value']
y = employment_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Employment (%)',fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Employment vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Employment_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %% [markdown]
# ## Working with Secondary Indicators

# %%
#Pull out selected education indicators for a deeper look into how education impacts HDI
education_indicators = ["Education Index",
                        "Labor force with basic education (% of total working-age population with basic education)",
                        "Labor force with intermediate education (% of total working-age population with intermediate education)",
                        "Labor force with advanced education (% of total working-age population with advanced education)",
                        "Government expenditure on education, total (% of GDP)",
                        "Literacy rate, adult total (% of people ages 15 and above)"]

secondary_indicators_education = combined_indicators_final[combined_indicators_final['indicator_name'].isin(education_indicators) ]

#Save to CSV
filepath = os.path.join('resources','education_df.csv')
secondary_indicators_education.to_csv(filepath)

#Preview data frame
secondary_indicators_education.head()

# %%
#Pull out selected gender indicators for a deeper look into how gender parity impacts HDI
gender_indicators = [
    "Gender Inequality Index",
    "Labor force, female (% of total labor force)",
    "Unemployment, female (% of female labor force) (modeled ILO estimate)",
    "School enrollment, primary (gross), gender parity index (GPI)",
    "School enrollment, secondary (gross), gender parity index (GPI)",
    "School enrollment, tertiary (gross), gender parity index (GPI)",
    "Proportion of seats held by women in national parliaments (%)"]

secondary_indicators_gender = combined_indicators_final[combined_indicators_final['indicator_name'].isin(gender_indicators) ]

#Save to CSV
filepath = os.path.join('resources','gender_df.csv')
secondary_indicators_gender.to_csv(filepath)

#Preview data frame
secondary_indicators_gender.head()

# %%
#Pull out selected accessiblity (to basic and technology needs) indicators for a deeper look into how access to these things impacts HDI
access_indicators = [
    "Mobile cellular subscriptions (per 100 people)",
    "Individuals using the Internet (% of population)",
    "People using at least basic drinking water services (% of population)",
    "Access to clean fuels and technologies for cooking (% of population)",
    "Access to electricity (% of population)",
    "People using at least basic sanitation services (% of population)"]

secondary_indicators_access = combined_indicators_final[combined_indicators_final['indicator_name'].isin(access_indicators) ]

#Save to CSV
filepath = os.path.join('resources','access_df.csv')
secondary_indicators_access.to_csv(filepath)

#Preview data frame
secondary_indicators_access.head()

# %%
#Create Education Index v. HDI chart
edu_1_values = secondary_indicators_education.loc[(secondary_indicators_education['indicator_name']=='Education Index')]

# defining variables
x = edu_1_values['value']
y = edu_1_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Education Index', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Education Index vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Education_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Workforce with Basic Education Index v. HDI chart
edu_2_values = secondary_indicators_education.loc[(secondary_indicators_education['indicator_name']=='Labor force with basic education (% of total working-age population with basic education)')]

# defining variables
x = edu_2_values['value']
y = edu_2_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Working Age Labor Force with Basic Education (%)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Workforce with Basic Education vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'WorkForceBasicEducation_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Workforce with Intermediate Education Index v. HDI chart
edu_3_values = secondary_indicators_education.loc[(secondary_indicators_education['indicator_name']=='Labor force with intermediate education (% of total working-age population with intermediate education)')]

# defining variables
x = edu_3_values['value']
y = edu_3_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Working Age Labor force with Intermediate Education (%)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Workforce with Intermediate Education vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'WorkForceIntermediateEducation_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Workforce with Advanced Education Index v. HDI chart
edu_4_values = secondary_indicators_education.loc[(secondary_indicators_education['indicator_name']=='Labor force with advanced education (% of total working-age population with advanced education)')]

# defining variables
x = edu_4_values['value']
y = edu_4_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Working Age Labor force with Advanced Education (%)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Workforce with Advanced Education vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'WorkForceAdvancedEducation_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Government Total Expenditure on Education v. HDI chart
edu_5_values = secondary_indicators_education.loc[(secondary_indicators_education['indicator_name']=='Government expenditure on education, total (% of GDP)')]

# defining variables
x = edu_5_values['value']
y = edu_5_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Government Total Expenditure on Education', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Government Total Expenditure on Education vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'ExpenditureEducation_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Adult Literacy Rate v. HDI chart
edu_6_values = secondary_indicators_education.loc[(secondary_indicators_education['indicator_name']=='Literacy rate, adult total (% of people ages 15 and above)')]

# defining variables
x = edu_6_values['value']
y = edu_6_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Adult Literacy Rate (% of people ages 15 and above)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Adult Literacy Rate vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Literacy_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Gender Inequality Index v. HDI chart
gender_1_values = secondary_indicators_gender.loc[(secondary_indicators_gender['indicator_name']=='Gender Inequality Index')]

# defining variables
x = gender_1_values['value']
y = gender_1_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Gender Inequality Index', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Gender Inequality Index vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'GII_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Female Unemployment v. HDI chart
gender_2_values = secondary_indicators_gender.loc[(secondary_indicators_gender['indicator_name']=='Unemployment, female (% of female labor force) (modeled ILO estimate)')]

# defining variables
x = gender_2_values['value']
y = gender_2_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Unemployed Female Percentage of Labor Force', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Unemployed Female Percentage of Labor Force vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Female_Unemployment_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Female Labor Force Percentage v. HDI chart
gender_3_values = secondary_indicators_gender.loc[(secondary_indicators_gender['indicator_name']=='Labor force, female (% of total labor force)')]

# defining variables
x = gender_3_values['value']
y = gender_3_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Labor Force, Female (% of total labor force)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Female Labor Force Percentage vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Female_Labor_Force.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Primary School enrollment Gender parity index (GPI) v. HDI chart
gender_4_values = secondary_indicators_gender.loc[(secondary_indicators_gender['indicator_name']=='School enrollment, primary (gross), gender parity index (GPI)')]

# defining variables
x = gender_4_values['value']
y = gender_4_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Primary School Enrollment (Gross), Gender Parity Index (GPI)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Primary School Enrollment Gender Parity Index vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Primary_GPI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Secondary School enrollment Gender parity index (GPI) v. HDI chart
gender_5_values = secondary_indicators_gender.loc[(secondary_indicators_gender['indicator_name']=='School enrollment, secondary (gross), gender parity index (GPI)')]

# defining variables
x = gender_5_values['value']
y = gender_5_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Secondary School Enrollment (Gross), Gender Parity Index (GPI)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Secondary School Enrollment Gender Parity Index vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Secondary_GPI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Tertiary School enrollment Gender tertiary index (GPI) v. HDI chart
gender_6_values = secondary_indicators_gender.loc[(secondary_indicators_gender['indicator_name']=='School enrollment, tertiary (gross), gender parity index (GPI)')]

# defining variables
x = gender_6_values['value']
y = gender_6_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Tertiary School Enrollment (Gross), Gender Parity Index (GPI)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Tertiary School Enrollment Gender Parity Index vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Tertiary_GPI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Percentage of Seats Held by Women in National Parliaments v. HDI chart
gender_7_values = secondary_indicators_gender.loc[(secondary_indicators_gender['indicator_name']=='Proportion of seats held by women in national parliaments (%)')]

# defining variables
x = gender_7_values['value']
y = gender_7_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Seats Held by Women in National Parliaments (%)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Seats Held by Women in National Parliaments vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Women_ParliamentSeats.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Mobile Subscriptions v. HDI chart
access_1_values = secondary_indicators_access.loc[(secondary_indicators_access['indicator_name']=='Mobile cellular subscriptions (per 100 people)')]

# defining variables
x = access_1_values['value']
y = access_1_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Mobile Cellular Subscriptions (per 100 people)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Mobile Subscriptions vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Mobile_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Access to Electricity v. HDI chart
access_2_values = secondary_indicators_access.loc[(secondary_indicators_access['indicator_name']=='Access to electricity (% of population)')]

# defining variables
x = access_2_values['value']
y = access_2_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Access to Electricity (% of population)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Access to Electricity vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Electric_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Percent of Population Using the Internet v. HDI chart
access_3_values = secondary_indicators_access.loc[(secondary_indicators_access['indicator_name']=='Individuals using the Internet (% of population)')]

# defining variables
x = access_3_values['value']
y = access_3_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Individuals using the Internet (% of population)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Percent of Population Using the Internet vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Internet_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Percent of Population with at least Drinking Water Services v. HDI chart
access_4_values = secondary_indicators_access.loc[(secondary_indicators_access['indicator_name']=='People using at least basic drinking water services (% of population)')]

# defining variables
x = access_4_values['value']
y = access_4_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Population Using at Least Basic Drinking Water Services (%)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Basic Drinking Water Services vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Water_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Percent of Population with Clean Fuels and Technologies for Cooking v. HDI chart
access_5_values = secondary_indicators_access.loc[(secondary_indicators_access['indicator_name']=='Access to clean fuels and technologies for cooking (% of population)')]

# defining variables
x = access_5_values['value']
y = access_5_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)
plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Population with clean fuels and technologies for cooking (%)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Clean Fuels and Technologies for Cooking vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Cooking_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)

# %%
#Create Percent of Population with at least Basic Sanitation Services v. HDI chart
access_6_values = secondary_indicators_access.loc[(secondary_indicators_access['indicator_name']=='People using at least basic sanitation services (% of population)')]

# defining variables
x = access_6_values['value']
y = access_6_values['hdi']

# linear regression stats and fitline
slope, intercept, r_value, p_value, _ = stats.linregress(x,y)
fit = intercept + slope*(np.array(x))

# Scatter plot
fig, ax = plt.subplots(figsize = (7,5))
ax.scatter(x, y, color="#233D4D", alpha=0.35, zorder=2)

plt.plot(x, fit, color="#D8D52B", label='fitted line', linewidth=0.8)
plt.grid(zorder=0)

plt.xlabel('Population using at least basic sanitation services (%)', fontsize=14)
plt.ylabel('HDI', fontsize=14)
plt.title("Basic Sanitation Services vs. HDI", fontsize=18)

# Show the figure
plt.tight_layout()
img_path = os.path.join('static/images', 'Sanitation_HDI.png')
plt.savefig(img_path, transparent=True)
plt.show()

print(r_value**2)
